# %% [markdown]
# # ALeRCE LSST, python client queries
#
# ```Author: Alejandra Muñoz Arancibia. Last updated: 260825```
#
# This notebook shows how to query the Rubin alert stream data (as well as derived properties) stored by the ALeRCE broker. We show examples of queries to our database tables and alert image cutouts (hereafter "stamps") via the ALeRCE python client, using the pandas package to manipulate output tables as dataframes.
#
# We refer to [this notebook](https://github.com/alercebroker/usecases/tree/master/notebooks/LSST/ALeRCE_LSST_Tables.ipynb) for a detailed description of how Rubin data are stored in the ALeRCE multistream database. Advanced queries not yet available for the python client can be done using Astronomical Data Query Language (ADQL) queries to the ALeRCE Table Access Protocol (TAP) service, as described in detail in [this notebook](https://github.com/alercebroker/usecases/tree/master/notebooks/LSST/ALeRCE_LSST_TAP_Queries.ipynb).
#
# *It is highly recommended that you try this notebook in Google Colab using the following [link](https://colab.research.google.com/github/alercebroker/usecases/blob/master/notebooks/LSST/ALeRCE_LSST_Client_Queries.ipynb).* This will avoid you from having to sort out library installation problems and focus on the contents of the tutorial. You can try installing the dependencies later in your own system.

# %% [markdown]
# # Table of contents
#
# * [Before starting](#before)
#     * [Some settings](#settings)
#     * [Initialize the ALeRCE client](#client)
#     * [LSST queries to the ALeRCE multisurvey database](#multisurvey)
#     * [Types of object identifiers](#sid)
# * [How to query individual objects](#query_one)
#     * [Query a diaObject](#query_diaobject)
#         * [Basic statistics](#object_one)
#         * [Light curves](#light_curves)
#         * [Stamps](#stamps)
#     * [Cone search](#conesearch)
# * [Querying samples of objects](#query_many)
#     * [Generate an ALeRCE LSST Explorer link](#explorer_url)
#     * [Object lists](#query_list)

# %% [markdown]
# ## Before starting <a class='anchor' id='before'></a>

# %% [markdown]
# ### Some settings <a class='anchor' id='settings'></a>

# %% [markdown]
# Install the [ALeRCE python client](https://alerce.readthedocs.io/en/latest/) uncommenting the following line. In case you have a previous alerce package version, note that you need to update it to version 2.2.1 or newer to retrieve Rubin data.

# %%
#!pip install alerce

# %% [markdown]
# We also use custom functions defined in ```lib_multisurvey```. In case you are using Google Colab, download this uncommenting the following line.

# %%
#!wget https://raw.githubusercontent.com/alercebroker/usecases/master/notebooks/LSST/lib_multisurvey/alerce_multisurvey_tools.py -P lib_multisurvey/

# %% [markdown]
# Load libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.cosmology import Planck18
from astropy.time import Time
import sys

# %%
from IPython.core.display import HTML
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)

# %%
from alerce.core import Alerce

# %% [markdown]
# ### Initialize the ALeRCE client <a class='anchor' id='client'></a>

# %%
alerce_client = Alerce()

# %% [markdown]
# ### LSST queries to the ALeRCE multisurvey database <a class='anchor' id='multisurvey'></a>

# %% [markdown]
# We save Rubin alert stream data in a multisurvey database. We distinguish among data sources by using the field ```tid```, for "telescope identifier". LSST (and more generally, all Rubin data observed with the Simonyi telescope) has ```tid = 1```.

# %%
tid = 1

# %% [markdown]
# ### Types of object identifiers <a class='anchor' id='sid'></a>

# %% [markdown]
# In LSST alerts, astrophysical objects have different identifiers depending on what they are associated to. Non-moving objects (e.g. supernovae, active galactic nuclei, variable stars) are associated to diaObjects, while known Solar System moving objects (e.g. asteroids) are associated to ssObjects. Identifiers for diaObjects and ssObjects are generated independent of each other by the lsst pipelines. We distinguish among them using the field ```sid```, for "survey identifier".
#
# We use the field ```oid``` as the identifier for each object. This ```oid``` is defined in different ways depending on the availability of diaObject information in the alert, so that
#
# ```oid = diaObjectId``` and ```sid = 1``` for objects that have diaObject information, and
#
# ```oid = ssObjectId``` and ```sid = 2``` if they only have ssObject information. In case an object has both identifiers (e.g. a known Solar System object was identified at a small angular distance from a non-moving object), we adopt ```oid = diaObjectId``` and ```sid = 1``` while still saving both their diaObject and ssObject data in the respective tables.
#
# We call the identifier for each epoch in every survey as ```measurement_id```. For LSST, this means both field ```diaSourceId``` for detections and field ```diaForcedSourceId``` for forced photometry points are renamed ```measurement_id``` in our database.

# %% [markdown]
# ## How to query individual objects <a class='anchor' id='query_one'></a>

# %% [markdown]
# Here we illustrate two examples of object queries: 1) a diaObject, and 2) a cone search. The first case is useful when the object identifier is known, while the second is useful to explore LSST data for an object from an external catalog whose equatorial coordinates are known. A third case, 3) a ssObject, is covered by TAP queries in [this notebook](https://github.com/alercebroker/usecases/tree/master/notebooks/LSST/ALeRCE_LSST_TAP_Queries.ipynb). Along these examples we show how to query several properties, like basic statistics, light curves, and stamps.

# %% [markdown]
# ### Query a diaObject <a class='anchor' id='query_diaobject'></a>

# %% [markdown]
# We choose ```oid = diaObjectId = 313853496686280764```, which can be found in the ALeRCE LSST Explorer as https://lsst.alerce.online/object/313853496686280764?survey=lsst. This object was reported to the [Transient Name Server](https://www.wis-tns.org/) based on ATLAS detections ([Tonry et al. 2025](https://www.wis-tns.org/object/2025agtf/discovery-cert)) and received the IAU name [AT 2025agtf](https://www.wis-tns.org/object/2025agtf). According to NED, its tentative host (WISEA J003724.47-422751.5) has redshift $z = 0.070493$.

# %%
oid = 313853496686280764
sid = 1
z_obj = 0.070493

# %% [markdown]
# #### Basic statistics <a class='anchor' id='object_one'></a>

# %% [markdown]
# We query the main properties of this object as

# %%
df_obj = alerce_client.query_object(oid=oid, survey='lsst',
                                    format='pandas')

# %%
display(df_obj)
# Out:
#                   oid  tid  sid   meanra    meandec       sigmara  \
# 0  313853496686280764    1    1  9.35233 -42.462751  1.279001e-07
#
#        sigmadec     firstmjd      lastmjd   deltamjd  n_det  n_forced  \
# 0  1.209322e-07  61024.13142  61233.40148  209.27006     73        25
#
#    n_non_det         created_date         updated_date
# 0          0  2026-02-13T00:00:00  2026-07-12T00:00:00

# %% [markdown]
# #### Light curves <a class='anchor' id='light_curves'></a>

# %% [markdown]
# We obtain its light curve (detections and forced photometry points) by using the ```query_detections``` and ```query_forced_photometry ```functions, or alternatively using the ```query_lightcurve``` function

# %%
df_dets = alerce_client.query_detections(oid, survey='lsst',
                                         format='pandas')
display(df_dets)
# Out:
#     band           mjd survey_id        ra        dec                 oid  \
# 0      3  61217.416228      lsst  9.352328 -42.462762  313853496686280764
# 1      1  61217.420025      lsst  9.352314 -42.462750  313853496686280764
# 2      3  61233.399660      lsst  9.352299 -42.462764  313853496686280764
# 3      1  61233.401480      lsst  9.352342 -42.462741  313853496686280764
# 4      3  61024.131420      lsst  9.352321 -42.462750  313853496686280764
# ..   ...           ...       ...       ...        ...                 ...
# 68     4  61060.078867      lsst  9.352332 -42.462751  313853496686280764
# 69     4  61060.079265      lsst  9.352351 -42.462739  313853496686280764
# 70     4  61060.080660      lsst  9.352330 -42.462747  313853496686280764
# 71     4  61060.081744      lsst  9.352319 -42.462754  313853496686280764
# 72     1  61069.071516      lsst  9.352305 -42.462750  313853496686280764
#
#         measurement_id  parentDiaSourceId         diaObjectId     psfFlux  \
# 0   170587116599771287                  0  313853496686280764  -3079.3540
# 1   170587117138214978                  0  313853496686280764   2097.8410
# 2   170657517458161746                  0  313853496686280764  -3406.0183
# 3   170657517570359340                  0  313853496686280764   1737.2053
# 4   313853496686280764                  0  313853496686280764  69393.8100
# ..                 ...                ...                 ...         ...
# 68  314011736304779269                  0  313853496686280764  77321.2900
# 69  314011736438997002                  0  313853496686280764  71776.1250
# 70  314011736707432455                  0  313853496686280764  77316.8300
# 71  314011736841650184                  0  313853496686280764  77870.9900
# 72  314051319512432679                  0  313853496686280764  18168.8830
#
#     psfFluxErr  psfFlux_flag  psfFlux_flag_edge  psfFlux_flag_noGoodPixels  \
# 0    182.27606             0                  0                          0
# 1     99.47668             0                  0                          0
# 2    254.18816             0                  0                          0
# 3    117.39891             0                  0                          0
# 4    434.88135             0                  0                          0
# ..         ...           ...                ...                        ...
# 68   601.81146             0                  0                          0
# 69   610.01200             1                  0                          0
# 70   598.63275             0                  0                          0
# 71   609.82120             0                  0                          0
# 72   452.46100             0                  0                          0
#
#     scienceFlux  scienceFluxErr  has_stamp          visit  detector  \
# 0     3734.6663      181.887940       True  2026062500645         6
# 1     3776.4712      100.853874       True  2026062500649         9
# 2     6157.6300      259.071530       True  2026071100884        75
# 3     4467.4970      119.216970       True  2026071100885        33
# 4    87073.4450      451.603730       True  2025121400756       176
# ..          ...             ...        ...            ...       ...
# 68   83513.7900      595.499700       True  2026011900085       184
# 69   79541.8200      613.229430       True  2026011900086       184
# 70   84569.5400      598.704400       True  2026011900088       184
# 71   85030.3100      607.790000       True  2026011900089       184
# 72   22119.1450      466.023300       True  2026012800091       153
#
#     ssObjectId     raErr    decErr    ra_dec_Cov           x      xErr  \
# 0            0  0.000019  0.000020  4.420417e-11  1464.21070  0.333903
# 1            0  0.000007  0.000009  4.072209e-12   421.74277  0.125876
# 2            0  0.000018  0.000018 -1.482970e-13  2074.84500  0.323735
# 3            0  0.000014  0.000015 -8.240756e-12  3138.43920  0.279099
# 4            0  0.000002  0.000002  5.811162e-14  2549.33800  0.035994
# ..         ...       ...       ...           ...         ...       ...
# 68           0  0.000002  0.000002 -5.092700e-13  3657.06470  0.035295
# 69           0  0.000002  0.000002 -3.890187e-13  3656.80320  0.041449
# 70           0  0.000002  0.000002 -6.984002e-13  3680.89600  0.036420
# 71           0  0.000002  0.000002 -3.080830e-13  3672.68000  0.035912
# 72           0  0.000007  0.000007 -3.080522e-12   543.95154  0.125411
#
#              y      yErr  centroid_flag      apFlux   apFluxErr  apFlux_flag  \
# 0    968.74110  0.376710          False  -4991.6196   589.52660        False
# 1   2665.00600  0.161196          False   1467.1781   272.74590        False
# 2    577.09326  0.327490          False  -3528.1040   602.20514        False
# 3   3195.62380  0.251385          False   2169.6208   256.88140        False
# 4   3547.10820  0.033921          False  70119.4300   652.02540        False
# ..         ...       ...            ...         ...         ...          ...
# 68   203.76839  0.030206          False  75619.2340  1116.71310        False
# 69   203.98784  0.038259           True  75038.1700  1124.57700         True
# 70   195.57700  0.029476          False  74840.0600  1116.29380        False
# 71   199.11755  0.032988          False  74781.3000  1117.41830        False
# 72  2655.21360  0.116445          False  18772.3800   846.54620        False
#
#     apFlux_flag_apertureTruncated  isNegative         snr psfLnL    psfChi2  \
# 0                           False        True   16.631289   None  1880.8595
# 1                           False       False   21.068914   None  1877.2717
# 2                           False        True   13.382581   None  1645.9456
# 3                           False       False   14.279624   None  1767.2616
# 4                           False       False  159.188460   None  1670.2264
# ..                            ...         ...         ...    ...        ...
# 68                          False       False  127.346620   None  1766.1859
# 69                          False       False  117.262390   None  2095.8477
# 70                          False       False  128.220980   None  1657.1554
# 71                          False       False  127.291990   None  1781.2291
# 72                          False       False   39.884087   None  1711.1840
#
#     psfNdata   trailFlux  trailFluxErr   trailRa trailRaErr   trailDec  \
# 0       1681  -3312.9521    183.474690  9.352332       None -42.462764
# 1       1681   2014.2294     63.781933  9.352314       None -42.462750
# 2       1681  -3295.3167    224.729920  9.352299       None -42.462766
# 3       1681   1629.6580     62.150677  9.352344       None -42.462740
# 4       1681  68759.9840      0.476512  9.352321       None -42.462750
# ..       ...         ...           ...       ...        ...        ...
# 68      1681  69344.5500      0.017640  9.352333       None -42.462749
# 69      1681         NaN           NaN       NaN       None        NaN
# 70      1681  73554.3900      0.158435  9.352333       None -42.462748
# 71      1681  76199.9450      1.048621  9.352318       None -42.462755
# 72      1681  19229.0660      0.744757  9.352303       None -42.462750
#
#    trailDecErr  trailLength  trailLengthErr  trailAngle  trailAngleErr  \
# 0         None     0.988732        0.209040  176.621480      13.596715
# 1         None     0.557504        0.234841   15.920236      25.409292
# 2         None     0.893750        0.444343 -140.789520      30.671530
# 3         None     0.798481        0.340409  109.717606      26.581459
# 4         None     0.585214             NaN  -84.049360            NaN
# ..         ...          ...             ...         ...            ...
# 68        None     0.773111             NaN  -67.853660            NaN
# 69        None          NaN             NaN         NaN            NaN
# 70        None     0.719743             NaN  -63.840122            NaN
# 71        None     0.715024             NaN  -73.308600            NaN
# 72        None     1.259496             NaN  -66.541820            NaN
#
#    trailChi2  trailNdata  trail_flag_edge dipoleMeanFlux dipoleMeanFluxErr  \
# 0       None           0            False           None              None
# 1       None           0            False           None              None
# 2       None           0            False           None              None
# 3       None           0            False           None              None
# 4       None           0            False           None              None
# ..       ...         ...              ...            ...               ...
# 68      None           0            False           None              None
# 69      None           0            False           None              None
# 70      None           0            False           None              None
# 71      None           0            False           None              None
# 72      None           0            False           None              None
#
#    dipoleFluxDiff dipoleFluxDiffErr dipoleLength dipoleAngle dipoleChi2  \
# 0            None              None         None        None       None
# 1            None              None         None        None       None
# 2            None              None         None        None       None
# 3            None              None         None        None       None
# 4            None              None         None        None       None
# ..            ...               ...          ...         ...        ...
# 68           None              None         None        None       None
# 69           None              None         None        None       None
# 70           None              None         None        None       None
# 71           None              None         None        None       None
# 72           None              None         None        None       None
#
#     dipoleNdata  forced_PsfFlux_flag  forced_PsfFlux_flag_edge  \
# 0             0                False                     False
# 1             0                False                     False
# 2             0                False                     False
# 3             0                False                     False
# 4             0                False                     False
# ..          ...                  ...                       ...
# 68            0                False                     False
# 69            0                 True                     False
# 70            0                False                     False
# 71            0                False                     False
# 72            0                False                     False
#
#     forced_PsfFlux_flag_noGoodPixels  templateFlux  templateFluxErr       ixx  \
# 0                              False     6918.8150        65.218550  0.183728
# 1                              False     1597.8499        33.828625  0.110753
# 2                              False     9608.1530        29.890340  0.261249
# 3                              False     2653.6140        18.241802  0.169417
# 4                              False    14675.6020         9.231125  0.457387
# ..                               ...           ...              ...       ...
# 68                             False     6152.5500        27.480574  0.277844
# 69                             False     6549.2812        19.249046  0.319620
# 70                             False     6288.4730        34.254795  0.280664
# 71                             False     6559.6895        24.190447  0.286184
# 72                             False     3657.6555        14.692997  0.386753
#
#          iyy       ixy    ixxPSF    iyyPSF    ixyPSF  shape_flag  \
# 0   0.201009  0.049316  0.102191  0.109693  0.012912       False
# 1   0.136963 -0.003952  0.117105  0.153027  0.006810       False
# 2   0.247742  0.034598  0.199355  0.198726  0.009906       False
# 3   0.199548 -0.025812  0.231934  0.215748  0.008143       False
# 4   0.431268  0.006412  0.462593  0.435522 -0.000829       False
# ..       ...       ...       ...       ...       ...         ...
# 68  0.235475 -0.015782  0.278460  0.236562 -0.021984       False
# 69  0.298392 -0.007730  0.295310  0.259388 -0.001120        True
# 70  0.240829 -0.010880  0.307790  0.236323 -0.015085       False
# 71  0.256061 -0.016501  0.298562  0.278909 -0.015727       False
# 72  0.326038 -0.067569  0.359938  0.358313 -0.060391       False
#
#     shape_flag_no_pixels  shape_flag_not_contained  shape_flag_parent_source  \
# 0                  False                     False                     False
# 1                  False                     False                     False
# 2                  False                     False                     False
# 3                  False                     False                     False
# 4                  False                     False                     False
# ..                   ...                       ...                       ...
# 68                 False                     False                     False
# 69                 False                     False                     False
# 70                 False                     False                     False
# 71                 False                     False                     False
# 72                 False                     False                     False
#
#     extendedness  reliability  isDipole  dipoleFitAttempted  \
# 0       0.829133     0.606399     False               False
# 1       0.023024     0.786226     False               False
# 2       0.321158     0.525943     False               False
# 3       0.159154     0.691402     False               False
# 4       0.001248     0.999998     False               False
# ..           ...          ...       ...                 ...
# 68      0.000071     1.000000     False               False
# 69           NaN     1.000000     False               False
# 70      0.011714     1.000000     False               False
# 71      0.026570     1.000000     False               False
# 72      0.000518     0.996428     False               False
#
#     timeProcessedMjdTai timeWithdrawnMjdTai  bboxSize  pixelFlags  \
# 0          61217.418142                None        17       False
# 1          61217.421427                None        17       False
# 2          61233.401419                None        20       False
# 3          61233.402865                None        22       False
# 4          61081.910089                None        75       False
# ..                  ...                 ...       ...         ...
# 68         61081.969365                None        32       False
# 69         61081.883300                None       100       False
# 70         61081.955545                None        33       False
# 71         61081.921294                None        37       False
# 72         61081.913153                None        33       False
#
#     pixelFlags_bad  pixelFlags_cr  pixelFlags_crCenter  pixelFlags_edge  \
# 0            False          False                False            False
# 1            False          False                False            False
# 2            False          False                False            False
# 3            False          False                False            False
# 4            False          False                False            False
# ..             ...            ...                  ...              ...
# 68           False          False                False            False
# 69           False          False                False            False
# 70           False          False                False            False
# 71           False          False                False            False
# 72           False          False                False            False
#
#     pixelFlags_nodata  pixelFlags_nodataCenter  pixelFlags_interpolated  \
# 0               False                    False                    False
# 1               False                    False                    False
# 2               False                    False                    False
# 3               False                    False                    False
# 4               False                    False                    False
# ..                ...                      ...                      ...
# 68              False                    False                    False
# 69              False                    False                    False
# 70              False                    False                    False
# 71              False                    False                    False
# 72              False                    False                    False
#
#     pixelFlags_interpolatedCenter  pixelFlags_offimage  pixelFlags_saturated  \
# 0                           False                False                 False
# 1                           False                False                 False
# 2                           False                False                 False
# 3                           False                False                 False
# 4                           False                False                 False
# ..                            ...                  ...                   ...
# 68                          False                False                 False
# 69                          False                False                 False
# 70                          False                False                 False
# 71                          False                False                 False
# 72                          False                False                 False
#
#     pixelFlags_saturatedCenter  pixelFlags_suspect  pixelFlags_suspectCenter  \
# 0                        False               False                     False
# 1                        False               False                     False
# 2                        False               False                     False
# 3                        False               False                     False
# 4                        False               False                     False
# ..                         ...                 ...                       ...
# 68                       False               False                     False
# 69                       False               False                     False
# 70                       False               False                     False
# 71                       False               False                     False
# 72                       False               False                     False
#
#     pixelFlags_streak  pixelFlags_streakCenter  pixelFlags_injected  \
# 0               False                    False                False
# 1               False                    False                False
# 2               False                    False                False
# 3               False                    False                False
# 4               False                    False                False
# ..                ...                      ...                  ...
# 68              False                    False                False
# 69              False                    False                False
# 70              False                    False                False
# 71              False                    False                False
# 72              False                    False                False
#
#     pixelFlags_injectedCenter  pixelFlags_injected_template  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
# ..                        ...                           ...
# 68                      False                         False
# 69                      False                         False
# 70                      False                         False
# 71                      False                         False
# 72                      False                         False
#
#     pixelFlags_injected_templateCenter  glint_trail band_name
# 0                                False        False         i
# 1                                False        False         g
# 2                                False        False         i
# 3                                False        False         g
# 4                                False        False         i
# ..                                 ...          ...       ...
# 68                               False        False         z
# 69                               False        False         z
# 70                               False        False         z
# 71                               False        False         z
# 72                               False        False         g
#
# [73 rows x 102 columns]

# %%
df_forced = alerce_client.query_forced_photometry(oid, survey='lsst',
                                                  format='pandas')
display(df_forced)
# Out:
#    band           mjd survey_id                 oid      measurement_id  \
# 0     3  61217.416228      lsst  313853496686280764  170587116599771137
# 1     3  61217.416705      lsst  313853496686280764  170587116732416003
# 2     1  61217.420025      lsst  313853496686280764  170587117138214918
# 3     1  61217.420491      lsst  313853496686280764  170587117274529797
# 4     3  61219.418592      lsst  313853496686280764  170595944404353032
# 5     3  61219.419089      lsst  313853496686280764  170595944516550666
# 6     1  61219.422467      lsst  313853496686280764  170595944920776707
# 7     1  61221.414491      lsst  313853496686280764  170604740459102212
# 8     3  61221.417075      lsst  313853496686280764  170604740767907843
# 9     3  61221.417571      lsst  313853496686280764  170604740900552706
#
#         ra        dec          visit  detector    psfFlux  psfFluxErr  \
# 0  9.35233 -42.462751  2026062500645         6 -3120.5054  184.691120
# 1  9.35233 -42.462751  2026062500646         3 -3095.1345  190.848650
# 2  9.35233 -42.462751  2026062500649         9  2137.9670  101.690490
# 3  9.35233 -42.462751  2026062500650        13  2098.6560   98.275085
# 4  9.35233 -42.462751  2026062700881        75 -3335.7505  462.655670
# 5  9.35233 -42.462751  2026062700882        33 -3201.1406  469.695160
# 6  9.35233 -42.462751  2026062700885        36  2490.6592  336.652280
# 7  9.35233 -42.462751  2026062900881         2  1264.1360  378.923700
# 8  9.35233 -42.462751  2026062900883        79 -3128.1174  332.779660
# 9  9.35233 -42.462751  2026062900884        76 -2670.1875  319.686370
#
#    scienceFlux  scienceFluxErr band_name
# 0    3710.6787       181.85367         i
# 1    3853.3070       188.72353         i
# 2    3762.2227       100.80308         g
# 3    3688.9807        97.85411         g
# 4   10570.1500       462.64578         i
# 5   11138.7010       470.44675         i
# 6    7772.0300       337.60376         g
# 7    3604.0315       381.72340         g
# 8    5599.7837       332.62410         i
# 9    5701.7710       319.06378         i

# %%
df_lc = alerce_client.query_lightcurve(oid, survey='lsst',
                                       format='pandas')
display(df_lc)

for col in df_lc.columns:
    print(col)
    display(pd.DataFrame(df_lc.loc[0, col]))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 detections  \
# 0  [{'band': 3, 'mjd': 61217.4162284394, 'survey_id': 'lsst', 'ra': 9.352328366643226, 'dec': -42.46276176132293, 'oid': 313853496686280764, 'measurement_id': 170587116599771287, 'parentDiaSourceId': 0, 'diaObjectId': 313853496686280764, 'psfFlux': -3079.354, 'psfFluxErr': 182.27606, 'psfFlux_flag': 0, 'psfFlux_flag_edge': 0, 'psfFlux_flag_noGoodPixels': 0, 'scienceFlux': 3734.6663, 'scienceFluxErr': 181.88794, 'has_stamp': True, 'visit': 2026062500645, 'detector': 6, 'ssObjectId': 0, 'raErr': 1.9370013e-05, 'decErr': 2.0124535e-05, 'ra_dec_Cov': 4.420417e-11, 'x': 1464.2107, 'xErr': 0.33390263, 'y': 968.7411, 'yErr': 0.37671006, 'centroid_flag': False, 'apFlux': -4991.6196, 'apFluxErr': 589.5266, 'apFlux_flag': False, 'apFlux_flag_apertureTruncated': False, 'isNegative': True, 'snr': 16.631289, 'psfLnL': None, 'psfChi2': 1880.8595, 'psfNdata': 1681, 'trailFlux': -3312.9521, 'trailFluxErr': 183.47469, 'trailRa': 9.352331938243108, 'trailRaErr': None, 'trailDec': -42.462763816148794, '...
#
#   non_detections  \
# 0             []
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          forced_photometry
# 0  [{'band': 3, 'mjd': 61217.4162284394, 'survey_id': 'lsst', 'oid': 313853496686280764, 'measurement_id': 170587116599771137, 'ra': 9.352330191901583, 'dec': -42.46275129777055, 'visit': 2026062500645, 'detector': 6, 'psfFlux': -3120.5054, 'psfFluxErr': 184.69112, 'scienceFlux': 3710.6787, 'scienceFluxErr': 181.85367, 'band_name': 'i'}, {'band': 3, 'mjd': 61217.41670499195, 'survey_id': 'lsst', 'oid': 313853496686280764, 'measurement_id': 170587116732416003, 'ra': 9.352330191901583, 'dec': -42.46275129777055, 'visit': 2026062500646, 'detector': 3, 'psfFlux': -3095.1345, 'psfFluxErr': 190.84865, 'scienceFlux': 3853.307, 'scienceFluxErr': 188.72353, 'band_name': 'i'}, {'band': 1, 'mjd': 61217.42002519088, 'survey_id': 'lsst', 'oid': 313853496686280764, 'measurement_id': 170587117138214918, 'ra': 9.35233018645261, 'dec': -42.462751296868674, 'visit': 2026062500649, 'detector': 9, 'psfFlux': 2137.967, 'psfFluxErr': 101.69049, 'scienceFlux': 3762.2227, 'scienceFluxErr': 100.80308, 'band_n...
# detections
#     band           mjd survey_id        ra        dec                 oid  \
# 0      3  61217.416228      lsst  9.352328 -42.462762  313853496686280764
# 1      1  61217.420025      lsst  9.352314 -42.462750  313853496686280764
# 2      3  61233.399660      lsst  9.352299 -42.462764  313853496686280764
# 3      1  61233.401480      lsst  9.352342 -42.462741  313853496686280764
# 4      3  61024.131420      lsst  9.352321 -42.462750  313853496686280764
# ..   ...           ...       ...       ...        ...                 ...
# 68     4  61060.078867      lsst  9.352332 -42.462751  313853496686280764
# 69     4  61060.079265      lsst  9.352351 -42.462739  313853496686280764
# 70     4  61060.080660      lsst  9.352330 -42.462747  313853496686280764
# 71     4  61060.081744      lsst  9.352319 -42.462754  313853496686280764
# 72     1  61069.071516      lsst  9.352305 -42.462750  313853496686280764
#
#         measurement_id  parentDiaSourceId         diaObjectId     psfFlux  \
# 0   170587116599771287                  0  313853496686280764  -3079.3540
# 1   170587117138214978                  0  313853496686280764   2097.8410
# 2   170657517458161746                  0  313853496686280764  -3406.0183
# 3   170657517570359340                  0  313853496686280764   1737.2053
# 4   313853496686280764                  0  313853496686280764  69393.8100
# ..                 ...                ...                 ...         ...
# 68  314011736304779269                  0  313853496686280764  77321.2900
# 69  314011736438997002                  0  313853496686280764  71776.1250
# 70  314011736707432455                  0  313853496686280764  77316.8300
# 71  314011736841650184                  0  313853496686280764  77870.9900
# 72  314051319512432679                  0  313853496686280764  18168.8830
#
#     psfFluxErr  psfFlux_flag  psfFlux_flag_edge  psfFlux_flag_noGoodPixels  \
# 0    182.27606             0                  0                          0
# 1     99.47668             0                  0                          0
# 2    254.18816             0                  0                          0
# 3    117.39891             0                  0                          0
# 4    434.88135             0                  0                          0
# ..         ...           ...                ...                        ...
# 68   601.81146             0                  0                          0
# 69   610.01200             1                  0                          0
# 70   598.63275             0                  0                          0
# 71   609.82120             0                  0                          0
# 72   452.46100             0                  0                          0
#
#     scienceFlux  scienceFluxErr  has_stamp          visit  detector  \
# 0     3734.6663      181.887940       True  2026062500645         6
# 1     3776.4712      100.853874       True  2026062500649         9
# 2     6157.6300      259.071530       True  2026071100884        75
# 3     4467.4970      119.216970       True  2026071100885        33
# 4    87073.4450      451.603730       True  2025121400756       176
# ..          ...             ...        ...            ...       ...
# 68   83513.7900      595.499700       True  2026011900085       184
# 69   79541.8200      613.229430       True  2026011900086       184
# 70   84569.5400      598.704400       True  2026011900088       184
# 71   85030.3100      607.790000       True  2026011900089       184
# 72   22119.1450      466.023300       True  2026012800091       153
#
#     ssObjectId     raErr    decErr    ra_dec_Cov           x      xErr  \
# 0            0  0.000019  0.000020  4.420417e-11  1464.21070  0.333903
# 1            0  0.000007  0.000009  4.072209e-12   421.74277  0.125876
# 2            0  0.000018  0.000018 -1.482970e-13  2074.84500  0.323735
# 3            0  0.000014  0.000015 -8.240756e-12  3138.43920  0.279099
# 4            0  0.000002  0.000002  5.811162e-14  2549.33800  0.035994
# ..         ...       ...       ...           ...         ...       ...
# 68           0  0.000002  0.000002 -5.092700e-13  3657.06470  0.035295
# 69           0  0.000002  0.000002 -3.890187e-13  3656.80320  0.041449
# 70           0  0.000002  0.000002 -6.984002e-13  3680.89600  0.036420
# 71           0  0.000002  0.000002 -3.080830e-13  3672.68000  0.035912
# 72           0  0.000007  0.000007 -3.080522e-12   543.95154  0.125411
#
#              y      yErr  centroid_flag      apFlux   apFluxErr  apFlux_flag  \
# 0    968.74110  0.376710          False  -4991.6196   589.52660        False
# 1   2665.00600  0.161196          False   1467.1781   272.74590        False
# 2    577.09326  0.327490          False  -3528.1040   602.20514        False
# 3   3195.62380  0.251385          False   2169.6208   256.88140        False
# 4   3547.10820  0.033921          False  70119.4300   652.02540        False
# ..         ...       ...            ...         ...         ...          ...
# 68   203.76839  0.030206          False  75619.2340  1116.71310        False
# 69   203.98784  0.038259           True  75038.1700  1124.57700         True
# 70   195.57700  0.029476          False  74840.0600  1116.29380        False
# 71   199.11755  0.032988          False  74781.3000  1117.41830        False
# 72  2655.21360  0.116445          False  18772.3800   846.54620        False
#
#     apFlux_flag_apertureTruncated  isNegative         snr psfLnL    psfChi2  \
# 0                           False        True   16.631289   None  1880.8595
# 1                           False       False   21.068914   None  1877.2717
# 2                           False        True   13.382581   None  1645.9456
# 3                           False       False   14.279624   None  1767.2616
# 4                           False       False  159.188460   None  1670.2264
# ..                            ...         ...         ...    ...        ...
# 68                          False       False  127.346620   None  1766.1859
# 69                          False       False  117.262390   None  2095.8477
# 70                          False       False  128.220980   None  1657.1554
# 71                          False       False  127.291990   None  1781.2291
# 72                          False       False   39.884087   None  1711.1840
#
#     psfNdata   trailFlux  trailFluxErr   trailRa trailRaErr   trailDec  \
# 0       1681  -3312.9521    183.474690  9.352332       None -42.462764
# 1       1681   2014.2294     63.781933  9.352314       None -42.462750
# 2       1681  -3295.3167    224.729920  9.352299       None -42.462766
# 3       1681   1629.6580     62.150677  9.352344       None -42.462740
# 4       1681  68759.9840      0.476512  9.352321       None -42.462750
# ..       ...         ...           ...       ...        ...        ...
# 68      1681  69344.5500      0.017640  9.352333       None -42.462749
# 69      1681         NaN           NaN       NaN       None        NaN
# 70      1681  73554.3900      0.158435  9.352333       None -42.462748
# 71      1681  76199.9450      1.048621  9.352318       None -42.462755
# 72      1681  19229.0660      0.744757  9.352303       None -42.462750
#
#    trailDecErr  trailLength  trailLengthErr  trailAngle  trailAngleErr  \
# 0         None     0.988732        0.209040  176.621480      13.596715
# 1         None     0.557504        0.234841   15.920236      25.409292
# 2         None     0.893750        0.444343 -140.789520      30.671530
# 3         None     0.798481        0.340409  109.717606      26.581459
# 4         None     0.585214             NaN  -84.049360            NaN
# ..         ...          ...             ...         ...            ...
# 68        None     0.773111             NaN  -67.853660            NaN
# 69        None          NaN             NaN         NaN            NaN
# 70        None     0.719743             NaN  -63.840122            NaN
# 71        None     0.715024             NaN  -73.308600            NaN
# 72        None     1.259496             NaN  -66.541820            NaN
#
#    trailChi2  trailNdata  trail_flag_edge dipoleMeanFlux dipoleMeanFluxErr  \
# 0       None           0            False           None              None
# 1       None           0            False           None              None
# 2       None           0            False           None              None
# 3       None           0            False           None              None
# 4       None           0            False           None              None
# ..       ...         ...              ...            ...               ...
# 68      None           0            False           None              None
# 69      None           0            False           None              None
# 70      None           0            False           None              None
# 71      None           0            False           None              None
# 72      None           0            False           None              None
#
#    dipoleFluxDiff dipoleFluxDiffErr dipoleLength dipoleAngle dipoleChi2  \
# 0            None              None         None        None       None
# 1            None              None         None        None       None
# 2            None              None         None        None       None
# 3            None              None         None        None       None
# 4            None              None         None        None       None
# ..            ...               ...          ...         ...        ...
# 68           None              None         None        None       None
# 69           None              None         None        None       None
# 70           None              None         None        None       None
# 71           None              None         None        None       None
# 72           None              None         None        None       None
#
#     dipoleNdata  forced_PsfFlux_flag  forced_PsfFlux_flag_edge  \
# 0             0                False                     False
# 1             0                False                     False
# 2             0                False                     False
# 3             0                False                     False
# 4             0                False                     False
# ..          ...                  ...                       ...
# 68            0                False                     False
# 69            0                 True                     False
# 70            0                False                     False
# 71            0                False                     False
# 72            0                False                     False
#
#     forced_PsfFlux_flag_noGoodPixels  templateFlux  templateFluxErr       ixx  \
# 0                              False     6918.8150        65.218550  0.183728
# 1                              False     1597.8499        33.828625  0.110753
# 2                              False     9608.1530        29.890340  0.261249
# 3                              False     2653.6140        18.241802  0.169417
# 4                              False    14675.6020         9.231125  0.457387
# ..                               ...           ...              ...       ...
# 68                             False     6152.5500        27.480574  0.277844
# 69                             False     6549.2812        19.249046  0.319620
# 70                             False     6288.4730        34.254795  0.280664
# 71                             False     6559.6895        24.190447  0.286184
# 72                             False     3657.6555        14.692997  0.386753
#
#          iyy       ixy    ixxPSF    iyyPSF    ixyPSF  shape_flag  \
# 0   0.201009  0.049316  0.102191  0.109693  0.012912       False
# 1   0.136963 -0.003952  0.117105  0.153027  0.006810       False
# 2   0.247742  0.034598  0.199355  0.198726  0.009906       False
# 3   0.199548 -0.025812  0.231934  0.215748  0.008143       False
# 4   0.431268  0.006412  0.462593  0.435522 -0.000829       False
# ..       ...       ...       ...       ...       ...         ...
# 68  0.235475 -0.015782  0.278460  0.236562 -0.021984       False
# 69  0.298392 -0.007730  0.295310  0.259388 -0.001120        True
# 70  0.240829 -0.010880  0.307790  0.236323 -0.015085       False
# 71  0.256061 -0.016501  0.298562  0.278909 -0.015727       False
# 72  0.326038 -0.067569  0.359938  0.358313 -0.060391       False
#
#     shape_flag_no_pixels  shape_flag_not_contained  shape_flag_parent_source  \
# 0                  False                     False                     False
# 1                  False                     False                     False
# 2                  False                     False                     False
# 3                  False                     False                     False
# 4                  False                     False                     False
# ..                   ...                       ...                       ...
# 68                 False                     False                     False
# 69                 False                     False                     False
# 70                 False                     False                     False
# 71                 False                     False                     False
# 72                 False                     False                     False
#
#     extendedness  reliability  isDipole  dipoleFitAttempted  \
# 0       0.829133     0.606399     False               False
# 1       0.023024     0.786226     False               False
# 2       0.321158     0.525943     False               False
# 3       0.159154     0.691402     False               False
# 4       0.001248     0.999998     False               False
# ..           ...          ...       ...                 ...
# 68      0.000071     1.000000     False               False
# 69           NaN     1.000000     False               False
# 70      0.011714     1.000000     False               False
# 71      0.026570     1.000000     False               False
# 72      0.000518     0.996428     False               False
#
#     timeProcessedMjdTai timeWithdrawnMjdTai  bboxSize  pixelFlags  \
# 0          61217.418142                None        17       False
# 1          61217.421427                None        17       False
# 2          61233.401419                None        20       False
# 3          61233.402865                None        22       False
# 4          61081.910089                None        75       False
# ..                  ...                 ...       ...         ...
# 68         61081.969365                None        32       False
# 69         61081.883300                None       100       False
# 70         61081.955545                None        33       False
# 71         61081.921294                None        37       False
# 72         61081.913153                None        33       False
#
#     pixelFlags_bad  pixelFlags_cr  pixelFlags_crCenter  pixelFlags_edge  \
# 0            False          False                False            False
# 1            False          False                False            False
# 2            False          False                False            False
# 3            False          False                False            False
# 4            False          False                False            False
# ..             ...            ...                  ...              ...
# 68           False          False                False            False
# 69           False          False                False            False
# 70           False          False                False            False
# 71           False          False                False            False
# 72           False          False                False            False
#
#     pixelFlags_nodata  pixelFlags_nodataCenter  pixelFlags_interpolated  \
# 0               False                    False                    False
# 1               False                    False                    False
# 2               False                    False                    False
# 3               False                    False                    False
# 4               False                    False                    False
# ..                ...                      ...                      ...
# 68              False                    False                    False
# 69              False                    False                    False
# 70              False                    False                    False
# 71              False                    False                    False
# 72              False                    False                    False
#
#     pixelFlags_interpolatedCenter  pixelFlags_offimage  pixelFlags_saturated  \
# 0                           False                False                 False
# 1                           False                False                 False
# 2                           False                False                 False
# 3                           False                False                 False
# 4                           False                False                 False
# ..                            ...                  ...                   ...
# 68                          False                False                 False
# 69                          False                False                 False
# 70                          False                False                 False
# 71                          False                False                 False
# 72                          False                False                 False
#
#     pixelFlags_saturatedCenter  pixelFlags_suspect  pixelFlags_suspectCenter  \
# 0                        False               False                     False
# 1                        False               False                     False
# 2                        False               False                     False
# 3                        False               False                     False
# 4                        False               False                     False
# ..                         ...                 ...                       ...
# 68                       False               False                     False
# 69                       False               False                     False
# 70                       False               False                     False
# 71                       False               False                     False
# 72                       False               False                     False
#
#     pixelFlags_streak  pixelFlags_streakCenter  pixelFlags_injected  \
# 0               False                    False                False
# 1               False                    False                False
# 2               False                    False                False
# 3               False                    False                False
# 4               False                    False                False
# ..                ...                      ...                  ...
# 68              False                    False                False
# 69              False                    False                False
# 70              False                    False                False
# 71              False                    False                False
# 72              False                    False                False
#
#     pixelFlags_injectedCenter  pixelFlags_injected_template  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
# ..                        ...                           ...
# 68                      False                         False
# 69                      False                         False
# 70                      False                         False
# 71                      False                         False
# 72                      False                         False
#
#     pixelFlags_injected_templateCenter  glint_trail band_name
# 0                                False        False         i
# 1                                False        False         g
# 2                                False        False         i
# 3                                False        False         g
# 4                                False        False         i
# ..                                 ...          ...       ...
# 68                               False        False         z
# 69                               False        False         z
# 70                               False        False         z
# 71                               False        False         z
# 72                               False        False         g
#
# [73 rows x 102 columns]
# non_detections
# Empty DataFrame
# Columns: []
# Index: []
# forced_photometry
#    band           mjd survey_id                 oid      measurement_id  \
# 0     3  61217.416228      lsst  313853496686280764  170587116599771137
# 1     3  61217.416705      lsst  313853496686280764  170587116732416003
# 2     1  61217.420025      lsst  313853496686280764  170587117138214918
# 3     1  61217.420491      lsst  313853496686280764  170587117274529797
# 4     3  61219.418592      lsst  313853496686280764  170595944404353032
# 5     3  61219.419089      lsst  313853496686280764  170595944516550666
# 6     1  61219.422467      lsst  313853496686280764  170595944920776707
# 7     1  61221.414491      lsst  313853496686280764  170604740459102212
# 8     3  61221.417075      lsst  313853496686280764  170604740767907843
# 9     3  61221.417571      lsst  313853496686280764  170604740900552706
#
#         ra        dec          visit  detector    psfFlux  psfFluxErr  \
# 0  9.35233 -42.462751  2026062500645         6 -3120.5054  184.691120
# 1  9.35233 -42.462751  2026062500646         3 -3095.1345  190.848650
# 2  9.35233 -42.462751  2026062500649         9  2137.9670  101.690490
# 3  9.35233 -42.462751  2026062500650        13  2098.6560   98.275085
# 4  9.35233 -42.462751  2026062700881        75 -3335.7505  462.655670
# 5  9.35233 -42.462751  2026062700882        33 -3201.1406  469.695160
# 6  9.35233 -42.462751  2026062700885        36  2490.6592  336.652280
# 7  9.35233 -42.462751  2026062900881         2  1264.1360  378.923700
# 8  9.35233 -42.462751  2026062900883        79 -3128.1174  332.779660
# 9  9.35233 -42.462751  2026062900884        76 -2670.1875  319.686370
#
#    scienceFlux  scienceFluxErr band_name
# 0    3710.6787       181.85367         i
# 1    3853.3070       188.72353         i
# 2    3762.2227       100.80308         g
# 3    3688.9807        97.85411         g
# 4   10570.1500       462.64578         i
# 5   11138.7010       470.44675         i
# 6    7772.0300       337.60376         g
# 7    3604.0315       381.72340         g
# 8    5599.7837       332.62410         i
# 9    5701.7710       319.06378         i

# %% [markdown]
# We display the columns that will be used to build the light curve. In this particular case, the object does not have forced photometry data

# %%
cols = ['measurement_id', 'band_name', 'mjd',
        'psfFlux', 'psfFluxErr', 'scienceFlux', 'scienceFluxErr']
display(df_dets[cols])
if len(df_forced) > 0:
    display(df_forced[cols])
# Out:
#         measurement_id band_name           mjd     psfFlux  psfFluxErr  \
# 0   170587116599771287         i  61217.416228  -3079.3540   182.27606
# 1   170587117138214978         g  61217.420025   2097.8410    99.47668
# 2   170657517458161746         i  61233.399660  -3406.0183   254.18816
# 3   170657517570359340         g  61233.401480   1737.2053   117.39891
# 4   313853496686280764         i  61024.131420  69393.8100   434.88135
# ..                 ...       ...           ...         ...         ...
# 68  314011736304779269         z  61060.078867  77321.2900   601.81146
# 69  314011736438997002         z  61060.079265  71776.1250   610.01200
# 70  314011736707432455         z  61060.080660  77316.8300   598.63275
# 71  314011736841650184         z  61060.081744  77870.9900   609.82120
# 72  314051319512432679         g  61069.071516  18168.8830   452.46100
#
#     scienceFlux  scienceFluxErr
# 0     3734.6663      181.887940
# 1     3776.4712      100.853874
# 2     6157.6300      259.071530
# 3     4467.4970      119.216970
# 4    87073.4450      451.603730
# ..          ...             ...
# 68   83513.7900      595.499700
# 69   79541.8200      613.229430
# 70   84569.5400      598.704400
# 71   85030.3100      607.790000
# 72   22119.1450      466.023300
#
# [73 rows x 7 columns]
#        measurement_id band_name           mjd    psfFlux  psfFluxErr  \
# 0  170587116599771137         i  61217.416228 -3120.5054  184.691120
# 1  170587116732416003         i  61217.416705 -3095.1345  190.848650
# 2  170587117138214918         g  61217.420025  2137.9670  101.690490
# 3  170587117274529797         g  61217.420491  2098.6560   98.275085
# 4  170595944404353032         i  61219.418592 -3335.7505  462.655670
# 5  170595944516550666         i  61219.419089 -3201.1406  469.695160
# 6  170595944920776707         g  61219.422467  2490.6592  336.652280
# 7  170604740459102212         g  61221.414491  1264.1360  378.923700
# 8  170604740767907843         i  61221.417075 -3128.1174  332.779660
# 9  170604740900552706         i  61221.417571 -2670.1875  319.686370
#
#    scienceFlux  scienceFluxErr
# 0    3710.6787       181.85367
# 1    3853.3070       188.72353
# 2    3762.2227       100.80308
# 3    3688.9807        97.85411
# 4   10570.1500       462.64578
# 5   11138.7010       470.44675
# 6    7772.0300       337.60376
# 7    3604.0315       381.72340
# 8    5599.7837       332.62410
# 9    5701.7710       319.06378

# %% [markdown]
# We show this light curve using a custom function defined in ```lib_multisurvey```

# %%
sys.path.append('./lib_multisurvey')
import alerce_multisurvey_tools as ms

# %% [markdown]
# We define some dictionaries to customize how to show the light curves. We will show both difference and science fluxes, including detections and (when available) forced photometry epochs

# %%
# More parameters (and their default values) defined in
# lib_multisurvey/alerce_multisurvey_tools.py, function plot_lc
lc_params = {
    'use_mag': False,
    'use_flux': True,
    'show_yr': False,
    'figwidth': 8,
    'pheight': 3,
    'fontsize': 9,
    'alpha': 0.5,
}

# %%
df_dets.set_index('oid', inplace=True)
if len(df_forced) > 0:
    df_forced.set_index('oid', inplace=True)

epochs = {
    'detections': df_dets,
    'forced_photometry': df_forced,
}

d_objs = ms.group_data_sid_oid(
    sid=sid,
    oid=oid,
    df_dets=epochs['detections'].copy(),
    df_forced=epochs['forced_photometry'].copy() \
        if oid in epochs['forced_photometry'].index else pd.DataFrame(),
    lc_kwargs=ms.init_lc_kwargs()
)

# %% [markdown]
# We show the light curves

# %%
d_objs[sid][oid]['lc_kwargs']['show_forced'] = True

ms.plot_lc(d_objs=d_objs, lc_params=lc_params)

# %% [markdown]
# We can show these light curves using magnitude units

# %%
d_objs[sid][oid]['lc_kwargs']['show_flux'] = False
d_objs[sid][oid]['lc_kwargs']['show_forced'] = False

ms.plot_lc(d_objs=d_objs, lc_params=lc_params)
# Out:
# /home/ammunoz1/.local/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [markdown]
# We can also show them using absolute magnitudes, assuming the redshift of the tentative host and the Planck 2018 cosmology

# %%
d_objs[sid][oid]['lc_kwargs']['show_absolute_mag'] = True
d_objs[sid][oid]['lc_kwargs']['z_obj'] = z_obj
d_objs[sid][oid]['lc_kwargs']['cosmo'] = Planck18

ms.plot_lc(d_objs=d_objs, lc_params=lc_params)

# %% [markdown]
# #### Stamps <a class='anchor' id='stamps'></a>

# %% [markdown]
# We show alert image cutouts for the first three detections of this object that triggered alerts. Note that not all stored detections may have triggered an alert, as they may come in an alert as previous detections. The field ```has_stamp``` in our detections dataframe indicates that a given detection triggered an alert, so that we can use it as a mask as

# %%
mask = epochs['detections']['has_stamp']
df_dets_this = epochs['detections'][mask].sort_values(by='mjd').iloc[0:3].copy()

cols = ['measurement_id', 'band_name', 'mjd',
        'psfFlux', 'psfFluxErr', 'scienceFlux', 'scienceFluxErr',
        'has_stamp']
display(df_dets_this[cols])
# Out:
#                         measurement_id band_name           mjd    psfFlux  \
# oid
# 313853496686280764  313853496686280764         i  61024.131420  69393.810
# 313853496686280764  313853498027933784         i  61024.138132  68777.630
# 313853496686280764  313853498568474633         i  61024.140180  68613.234
#
#                     psfFluxErr  scienceFlux  scienceFluxErr  has_stamp
# oid
# 313853496686280764   434.88135    87073.445       451.60373       True
# 313853496686280764   369.12128    80362.010       372.00574       True
# 313853496686280764   369.33966    79989.170       374.35675       True

# %% [markdown]
# We retrieve the stamps, obtaining the main fields: Science, Template and Difference

# %%
for i, row in df_dets_this.iterrows():
    params = {
        'survey': 'lsst',
        'oid': i,
        'measurement_id': row['measurement_id'],
    }
    df_stamps = alerce_client.plot_stamps(**params)

# %% [markdown]
# We show the same stamps, but using a custom function defined in ```alerce_multisurvey_tools.py```. This requires querying the stamps using the client function ```get_stamps```, that also retrieves the stamps headers

# %%
fontsize = 8

# %%
def set_title(oid=None, sid=None, row=None):
    col_flux = 'psfFlux'
    col_flux_err = 'psfFluxErr'

    title = ms.sid_num2str[sid] + ', oid=' + str(oid) + ', ' \
            + 'measurement_id=' + str(row['measurement_id']) + '\n' \
            + 'band=' + row['band_name'] + ', ' \
            + 'mjd=%.4f' % row['mjd'] + ', ' \
            + 'S/N=%.2f' % row['snr'] + ', ' \
            + 'psfFlux=%.f' % row[col_flux] + '+-' \
            + '%.f uJy' % row[col_flux_err]

    return title

# %%
df_stamps = ms.query_stamps(client=alerce_client, df_objs=df_dets_this,
                            survey='lsst', sid=sid)
print(df_stamps.columns)
# Out:
# Index(['measurement_id', 'flux_Science_data', 'flux_Science_header',
#        'flux_Template_data', 'flux_Template_header', 'flux_Difference_data',
#        'flux_Difference_header'],
#       dtype='object')

# %% [markdown]
# We show how this table looks like for the first detection

# %%
display(df_stamps.iloc[[0]])
# Out:
#                         measurement_id  \
# oid
# 313853496686280764  313853496686280764
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           flux_Science_data  \
# oid
# 313853496686280764  [[25.634619, 57.166313, 41.000713, 65.75837, 82.64125, 124.294205, 78.24482, 86.1664, 96.42443, 145.5963, 155.44913, 175.60265, 208.51073, 228.70111, 186.00323, 235.86365, 262.40945, 233.65773, 294.73758, 330.11145, 366.7661, 364.62842, 386.98178, 368.0958, 330.7721, 407.3403, 419.8131, 485.17136, 501.75894, 515.5518, 541.33264, 517.8899, 574.0795, 611.398, 622.6798, 613.9455, 674.4292, 676.4349, 659.40875, 762.507, 713.6062, 740.25684, 796.5863, 808.67316, 855.56934, 856.0238, 746.8455, 773.91876, 769.3547, 705.9671, 697.12366, 653.126, 562.6073, 596.1889, 535.3055, 452.37326, 458.91544, 381.73355, 391.91928, 345.11447, 333.76352, 299.51566, 228.96292, 269.00406, 212.97893, 140.0318, 154.80754, 176.52869, 216.24498, 154.90744, 179.71664, 136.55736, 122.45753, 147.33728, 147.37453], [39.894855, 5.6752105, 89.82441, 99.56032, 24.605724, 37.184338, 86.261795, 85.18595, 119.025215, 114.81206, 135.7805, 183.8508, 166.60643, 206.44016, 210.82515, 245.94827, 319.29678, 296.16672, 269.458...
#
#                                                                                                                                                                                       flux_Science_header  \
# oid
# 313853496686280764  [SIMPLE, BITPIX, NAXIS, NAXIS1, NAXIS2, EXTEND, CUTMINX, CUTMINY, ROTPA, BUNIT, WCSAXES, CRPIX1, CRPIX2, PC1_1, PC1_2, PC2_1, PC2_2, CDELT1, CDELT2, CRVAL1, CRVAL2, LATPOLE, MJDREF]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          flux_Template_data  \
# oid
# 313853496686280764  [[44.957737, 49.382427, 56.25625, 64.27454, 65.76483, 76.85747, 87.536705, 96.2348, 113.2325, 131.48213, 137.49619, 153.15123, 179.93071, 202.6308, 229.57352, 249.93138, 274.06842, 289.36993, 304.8607, 331.18536, 341.48184, 346.00275, 355.7191, 374.73062, 392.51474, 416.74866, 437.7989, 462.71286, 489.5546, 511.9513, 521.5904, 529.20135, 540.3992, 556.1149, 561.6992, 587.4123, 609.93475, 629.0428, 652.5889, 680.06696, 699.7645, 717.57635, 733.7042, 742.8905, 750.57635, 750.6055, 744.0125, 727.4067, 704.4606, 667.83435, 625.63074, 587.67346, 543.8762, 506.22336, 466.445, 432.01193, 396.31833, 369.42847, 348.81638, 320.01495, 291.4542, 269.75775, 245.04973, 223.21803, 211.55083, 198.13826, 177.48073, 162.4066, 151.76036, 138.73038, 128.16692, 118.72001, 112.37468, 104.99711, 101.497894], [44.141315, 49.24643, 55.83285, 63.46123, 73.844986, 73.9895, 88.347466, 99.47101, 108.739746, 124.76812, 146.82593, 160.17114, 178.67467, 201.62592, 227.3952, 249.04594, 273.77353, 290.4775, 312.333...
#
#                                                                                                                                                                                      flux_Template_header  \
# oid
# 313853496686280764  [SIMPLE, BITPIX, NAXIS, NAXIS1, NAXIS2, EXTEND, CUTMINX, CUTMINY, ROTPA, BUNIT, WCSAXES, CRPIX1, CRPIX2, PC1_1, PC1_2, PC2_1, PC2_2, CDELT1, CDELT2, CRVAL1, CRVAL2, LATPOLE, MJDREF]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        flux_Difference_data  \
# oid
# 313853496686280764  [[-22.501293, 3.2864718, -18.78829, 0.36491063, 10.276537, 43.098007, -13.602087, -17.792112, -20.966982, 13.905411, 6.425154, 8.1363325, 22.380741, 22.954433, -39.424408, -9.936282, -2.8707728, -52.015125, -10.268051, 11.268102, 34.73679, 13.044429, 15.98176, -18.610245, -73.88947, -17.117577, -26.365656, 17.858828, 14.267151, 9.656484, 16.683697, -25.488258, 14.237983, 34.60879, 26.004568, -3.355023, 32.903854, 8.822168, -36.275425, 39.667923, -37.510567, -36.693832, -1.9037528, -7.128325, 30.587336, 31.38732, -68.967445, -23.3957, 1.8333588, -27.138443, 2.387222, 3.45298, -42.66016, 35.271294, 17.01156, -26.489922, 17.325169, -23.748398, 20.776052, 2.3754163, 17.034698, 8.768429, -39.40991, 21.089876, -14.398326, -68.28452, -38.102634, -2.5283554, 51.27497, 2.7884052, 39.076935, 5.0677247, 0.5898175, 33.575893, 40.77051], [-8.0967655, -47.93929, 30.795143, 35.113575, -47.05391, -44.76054, -5.3044167, -17.87774, 1.1681021, -18.357664, -12.526004, 17.819305, -20.887491, -2.4253778...
#
#                                                                                                                                                                                    flux_Difference_header
# oid
# 313853496686280764  [SIMPLE, BITPIX, NAXIS, NAXIS1, NAXIS2, EXTEND, CUTMINX, CUTMINY, ROTPA, BUNIT, WCSAXES, CRPIX1, CRPIX2, PC1_1, PC1_2, PC2_1, PC2_2, CDELT1, CDELT2, CRVAL1, CRVAL2, LATPOLE, MJDREF]

# %%
for i, row_this in df_dets_this.iterrows():
    mask = df_stamps.loc[[i]]['measurement_id'] == row_this['measurement_id']
    obj = df_stamps.loc[[i]][mask]
    
    for i, row in obj.iterrows():
        title = set_title(oid=i, sid=sid, row=row_this)
        ms.plot_stamps(row, title=title, fontsize=fontsize)

# %% [markdown]
# Note that LSST images are not always aligned. We use the header WCS to show stamps including equatorial coordinates. We continue this section showing only stamps for the first detection

# %%
df_dets_this = df_dets_this[~df_dets_this.index.duplicated(keep='first')].copy()
display(df_dets_this)
# Out:
#                     band          mjd survey_id        ra       dec  \
# oid
# 313853496686280764     3  61024.13142      lsst  9.352321 -42.46275
#
#                         measurement_id  parentDiaSourceId         diaObjectId  \
# oid
# 313853496686280764  313853496686280764                  0  313853496686280764
#
#                      psfFlux  psfFluxErr  psfFlux_flag  psfFlux_flag_edge  \
# oid
# 313853496686280764  69393.81   434.88135             0                  0
#
#                     psfFlux_flag_noGoodPixels  scienceFlux  scienceFluxErr  \
# oid
# 313853496686280764                          0    87073.445       451.60373
#
#                     has_stamp          visit  detector  ssObjectId     raErr  \
# oid
# 313853496686280764       True  2025121400756       176           0  0.000002
#
#                       decErr    ra_dec_Cov         x      xErr          y  \
# oid
# 313853496686280764  0.000002  5.811162e-14  2549.338  0.035994  3547.1082
#
#                         yErr  centroid_flag    apFlux  apFluxErr  apFlux_flag  \
# oid
# 313853496686280764  0.033921          False  70119.43   652.0254        False
#
#                     apFlux_flag_apertureTruncated  isNegative        snr  \
# oid
# 313853496686280764                          False       False  159.18846
#
#                    psfLnL    psfChi2  psfNdata  trailFlux  trailFluxErr  \
# oid
# 313853496686280764   None  1670.2264      1681  68759.984      0.476512
#
#                      trailRa trailRaErr  trailDec trailDecErr  trailLength  \
# oid
# 313853496686280764  9.352321       None -42.46275        None     0.585214
#
#                     trailLengthErr  trailAngle  trailAngleErr trailChi2  \
# oid
# 313853496686280764             NaN   -84.04936            NaN      None
#
#                     trailNdata  trail_flag_edge dipoleMeanFlux  \
# oid
# 313853496686280764           0            False           None
#
#                    dipoleMeanFluxErr dipoleFluxDiff dipoleFluxDiffErr  \
# oid
# 313853496686280764              None           None              None
#
#                    dipoleLength dipoleAngle dipoleChi2  dipoleNdata  \
# oid
# 313853496686280764         None        None       None            0
#
#                     forced_PsfFlux_flag  forced_PsfFlux_flag_edge  \
# oid
# 313853496686280764                False                     False
#
#                     forced_PsfFlux_flag_noGoodPixels  templateFlux  \
# oid
# 313853496686280764                             False     14675.602
#
#                     templateFluxErr       ixx       iyy       ixy    ixxPSF  \
# oid
# 313853496686280764         9.231125  0.457387  0.431268  0.006412  0.462593
#
#                       iyyPSF    ixyPSF  shape_flag  shape_flag_no_pixels  \
# oid
# 313853496686280764  0.435522 -0.000829       False                 False
#
#                     shape_flag_not_contained  shape_flag_parent_source  \
# oid
# 313853496686280764                     False                     False
#
#                     extendedness  reliability  isDipole  dipoleFitAttempted  \
# oid
# 313853496686280764      0.001248     0.999998     False               False
#
#                     timeProcessedMjdTai timeWithdrawnMjdTai  bboxSize  \
# oid
# 313853496686280764         61081.910089                None        75
#
#                     pixelFlags  pixelFlags_bad  pixelFlags_cr  \
# oid
# 313853496686280764       False           False          False
#
#                     pixelFlags_crCenter  pixelFlags_edge  pixelFlags_nodata  \
# oid
# 313853496686280764                False            False              False
#
#                     pixelFlags_nodataCenter  pixelFlags_interpolated  \
# oid
# 313853496686280764                    False                    False
#
#                     pixelFlags_interpolatedCenter  pixelFlags_offimage  \
# oid
# 313853496686280764                          False                False
#
#                     pixelFlags_saturated  pixelFlags_saturatedCenter  \
# oid
# 313853496686280764                 False                       False
#
#                     pixelFlags_suspect  pixelFlags_suspectCenter  \
# oid
# 313853496686280764               False                     False
#
#                     pixelFlags_streak  pixelFlags_streakCenter  \
# oid
# 313853496686280764              False                    False
#
#                     pixelFlags_injected  pixelFlags_injectedCenter  \
# oid
# 313853496686280764                False                      False
#
#                     pixelFlags_injected_template  \
# oid
# 313853496686280764                         False
#
#                     pixelFlags_injected_templateCenter  glint_trail band_name
# oid
# 313853496686280764                               False        False         i

# %% [markdown]
# We show the header for the Science cutout

# %%
row_this = df_stamps.iloc[0].copy()
display(row_this['flux_Science_header'])
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   75
# NAXIS2  =                   75
# EXTEND  =                    T
# CUTMINX =                 2511
# CUTMINY =                 3509
# ROTPA   =     352.530439684183 / Pos angle in deg of focal plane +Y wrt North
# BUNIT   = 'nJy     '
# WCSAXES =                    2 / Number of coordinate axes
# CRPIX1  =      38.337831164878 / Pixel coordinate of reference point
# CRPIX2  =      38.108262705427 / Pixel coordinate of reference point
# PC1_1   = -5.5105250623049E-05 / Coordinate transformation matrix element
# PC1_2   =  -6.828276014008E-06 / Coordinate transformation matrix element
# PC2_1   = -6.8682594550794E-06 / Coordinate transformation matrix element
# PC2_2   =  5.5013546735598E-05 / Coordinate transformation matrix element
# CDELT1  =                  1.0 / Coordinate increment at reference point
# CDELT2  =                  1.0 / Coordinate increment at reference point
# CRVAL1  =      9.3523212304437 / Coordinate value at reference point
# CRVAL2  =     -42.462749921193 / Coordinate value at reference point
# LATPOLE =                 90.0 / [deg] Native latitude of celestial pole
# MJDREF  =                  0.0 / [d] MJD of fiducial time

# %% [markdown]
# Having the header data, we can plot stamps including WCS axes

# %%
for j, row_this in df_dets_this.iterrows():
    mask = df_stamps.loc[[j]]['measurement_id'] == row_this['measurement_id']
    obj = df_stamps.loc[[j]][mask]
    
    for i, row in obj.iterrows():
        title = set_title(oid=i, sid=sid, row=row_this)
        ms.plot_stamps(row, title=title, fontsize=fontsize,
                       use_wcs=True, figsize=[8, 8], title_offset=0.68)

# %% [markdown]
# The client function ```get_stamps``` also allows to retrieve additional planes included in LSST stamps, i.e. variance and PSF. We can compute the image shape of each plane and cutout type

# %%
include_variance_and_psf = True

df_stamps = ms.query_stamps(
    client=alerce_client,
    df_objs=df_dets_this,
    survey='lsst',
    sid=sid,
    include_variance_and_psf=include_variance_and_psf
)
print(df_stamps.columns)
# Out:
# Index(['measurement_id', 'flux_Science_data', 'flux_Science_header',
#        'flux_Template_data', 'flux_Template_header', 'flux_Difference_data',
#        'flux_Difference_header', 'variance_Science_data',
#        'variance_Science_header', 'variance_Template_data',
#        'variance_Template_header', 'variance_Difference_data',
#        'variance_Difference_header', 'psf_Science_data', 'psf_Science_header',
#        'psf_Template_data', 'psf_Template_header', 'psf_Difference_data',
#        'psf_Difference_header'],
#       dtype='object')

# %%
cols = []
for plane in ms.image_planes:
    cols += [plane + '_' + x + '_data' for x in ms.image_subtypes]
#print(cols)

for col in cols:
    df_stamps[col.replace('data', 'shape')] = [x.shape for x in df_stamps[col]]
display(df_stamps[['measurement_id'] + [x.replace('data', 'shape') for x in cols]])
# Out:
#                         measurement_id flux_Science_shape flux_Template_shape  \
# oid
# 313853496686280764  313853496686280764           (75, 75)            (75, 75)
#
#                    flux_Difference_shape variance_Science_shape  \
# oid
# 313853496686280764              (75, 75)               (75, 75)
#
#                    variance_Template_shape variance_Difference_shape  \
# oid
# 313853496686280764                (75, 75)                  (75, 75)
#
#                    psf_Science_shape psf_Template_shape psf_Difference_shape
# oid
# 313853496686280764          (41, 41)           (43, 43)             (41, 41)

# %% [markdown]
# We plot all planes for the stamps shown above

# %%
for j, row_this in df_dets_this.iterrows():
    mask = df_stamps.loc[[j]]['measurement_id'] == row_this['measurement_id']
    obj = df_stamps.loc[[j]][mask]
    
    for i, row in obj.iterrows():
        title = set_title(oid=i, sid=sid, row=row_this)
        for plane in ms.image_planes:
            title_aux = title if plane == 'flux' else plane
            title_offset = 0.72 if plane == 'flux' else 0.7
            ms.plot_stamps(row, plane=plane, title=title_aux,
                           fontsize=fontsize, title_offset=title_offset)

# %% [markdown]
# ### Cone search <a class='anchor' id='conesearch'></a>

# %% [markdown]
# Let us say we want to know if the known RRLab star SSS_J004408.1-432806 has triggered Rubin alerts. This star has equatorial coordinates (11.03301, -43.46871) deg and a period of 0.546472 d in VSX (see https://vsx.aavso.org/index.php?view=detail.top&oid=479455). We use a cone search with a small radius (e.g. 1.5 arcsec)

# %%
ra = 11.03301
dec = -43.46871
period = 0.546472
radius = 1.5

# %% [markdown]
# Note that you need to provide object coordinates in equatorial system in deg, and search radius in arcsec

# %%
df_obj = alerce_client.query_objects(
    survey='lsst',
    ra=ra,
    dec=dec,
    radius=radius
)
df_obj
# Out:
#                   oid  tid  sid    meanra    meandec       sigmara  \
# 0  313629129709715483    1    1  11.03329 -43.468726  3.745349e-07
# 1  313629129709715483    1    1  11.03329 -43.468726  3.745349e-07
#
#        sigmadec      firstmjd       lastmjd    deltamjd  n_det  n_forced  \
# 0  3.671554e-07  60973.170251  61235.404704  262.234452     62        32
# 1  3.671554e-07  60973.170251  61235.404704  262.234452     62        32
#
#    n_non_det stellar class_name                       classifier_name  \
# 0          0    None         VS           stamp_classifier_rubin_beta
# 1          0    None         VS  stamp_classifier_rubin_beta_20260421
#
#   classifier_version  probability  ranking
# 0              2.0.1     0.984722        1
# 1              2.0.2     0.918616        1

# %% [markdown]
# Now that we know the object identifier in LSST (and its ```sid```) we can query other data as before. In particular, we obtain its light curve and show it also as a folded light curve using the known period

# %%
oid = df_obj.iloc[0]['oid']
sid = df_obj.iloc[0]['sid']

# %%
df_dets = alerce_client.query_detections(oid, survey='lsst',
                                         format='pandas')
display(df_dets)
# Out:
#     band           mjd survey_id         ra        dec                 oid  \
# 0      3  61217.416228      lsst  11.033261 -43.468719  313629129709715483
# 1      1  61219.422467      lsst  11.033311 -43.468733  313629129709715483
# 2      1  61219.422929      lsst  11.033320 -43.468739  313629129709715483
# 3      3  61221.417075      lsst  11.033095 -43.468658  313629129709715483
# 4      4  61222.414153      lsst  11.033290 -43.468699  313629129709715483
# ..   ...           ...       ...        ...        ...                 ...
# 57     3  61049.096454      lsst  11.033295 -43.468714  313629129709715483
# 58     3  61049.096929      lsst  11.033268 -43.468731  313629129709715483
# 59     2  61060.062098      lsst  11.033297 -43.468733  313629129709715483
# 60     4  61060.079265      lsst  11.033273 -43.468745  313629129709715483
# 61     4  61060.081744      lsst  11.033242 -43.468726  313629129709715483
#
#         measurement_id  parentDiaSourceId         diaObjectId     psfFlux  \
# 0   170587116609732722                  0  313629129709715483  40800.1640
# 1   170595944914485287                  0  313629129709715483 -11971.8640
# 2   170595945045033006                  0  313629129709715483 -12225.1800
# 3   170604740730683475                  0  313629129709715483   7190.7856
# 4   170609125892292624                  0  313629129709715483  12540.0100
# ..                 ...                ...                 ...         ...
# 57  313963355348926501                  0  313629129709715483  48877.9100
# 58  313963355480522797                  0  313629129709715483  47225.4340
# 59  314011733589491776                  0  313629129709715483  38450.7200
# 60  314011736429559819                  0  313629129709715483  21062.5820
# 61  314011736832213001                  0  313629129709715483  22092.1680
#
#     psfFluxErr  psfFlux_flag  psfFlux_flag_edge  psfFlux_flag_noGoodPixels  \
# 0    390.77722             0                  0                          0
# 1    392.59177             0                  0                          0
# 2    388.54520             0                  0                          0
# 3    391.61493             0                  0                          0
# 4    634.99384             0                  0                          0
# ..         ...           ...                ...                        ...
# 57   535.02410             0                  0                          0
# 58   528.66833             0                  0                          0
# 59   373.71188             0                  0                          0
# 60   598.87580             0                  0                          0
# 61   634.87940             0                  0                          0
#
#     scienceFlux  scienceFluxErr  has_stamp          visit  detector  \
# 0    138784.830       415.62857       True  2026062500645        25
# 1     66784.120       409.57086       True  2026062700885        24
# 2     66231.870       404.22772       True  2026062700886        17
# 3     72630.125       399.34390       True  2026062900883         8
# 4    113239.500       647.66580       True  2026063000787         8
# ..          ...             ...        ...            ...       ...
# 57   150319.720       567.09796       True  2026010800067       130
# 58   148227.340       558.06110       True  2026010800068       125
# 59   138034.340       379.44990       True  2026011900065       125
# 60   123199.440       603.43176       True  2026011900086       166
# 61   123998.280       640.85626       True  2026011900089       166
#
#     ssObjectId     raErr    decErr    ra_dec_Cov           x      xErr  \
# 0            0  0.000001  0.000001 -6.455706e-14   348.96478  0.023316
# 1            0  0.000009  0.000009 -4.753430e-13  3173.40330  0.167469
# 2            0  0.000009  0.000009  3.306157e-12  1798.48070  0.149785
# 3            0  0.000008  0.000010  2.039559e-12   256.00986  0.181827
# 4            0  0.000047  0.000015  3.145171e-10  2138.81600  0.246993
# ..         ...       ...       ...           ...         ...       ...
# 57           0  0.000004  0.000003 -4.144399e-13  3174.94000  0.067368
# 58           0  0.000004  0.000003 -2.743937e-13  3309.83200  0.064831
# 59           0  0.000002  0.000002 -4.367967e-13  1883.58720  0.042067
# 60           0  0.000007  0.000007 -5.161000e-12   457.09094  0.129067
# 61           0  0.000007  0.000007 -7.804510e-12   472.92966  0.138615
#
#              y      yErr  centroid_flag      apFlux   apFluxErr  apFlux_flag  \
# 0   3254.19800  0.022351          False  42371.8800   627.31640        False
# 1    262.41165  0.166698          False -11393.9420   593.73420        False
# 2   1078.80580  0.156934          False -11236.5120   590.20020        False
# 3   3383.09600  0.149870          False   7353.4824   831.70557        False
# 4    762.44885  0.849051          False  14930.5740  1178.06340        False
# ..         ...       ...            ...         ...         ...          ...
# 57  2817.38570  0.062002          False  49154.4650   706.04193        False
# 58  2978.43120  0.059933          False  47712.4400   709.67850        False
# 59  2936.36870  0.036571          False  38228.9530   495.24057        False
# 60   499.49040  0.115215          False  22086.7900  1086.72130        False
# 61   495.03293  0.118690          False  23453.0350  1083.94530        False
#
#     apFlux_flag_apertureTruncated  isNegative         snr psfLnL    psfChi2  \
# 0                           False       False  102.795944   None  2486.8930
# 1                           False        True   30.240448   None  1715.7645
# 2                           False        True   31.055980   None  1763.8862
# 3                           False       False   18.470304   None  1787.3040
# 4                           False       False   19.729780   None  1824.4369
# ..                            ...         ...         ...    ...        ...
# 57                          False       False   91.234600   None  1639.4149
# 58                          False       False   89.105460   None  1624.9680
# 59                          False       False  101.787470   None  1676.1233
# 60                          False       False   34.878036   None  1698.4476
# 61                          False       False   34.775978   None  1709.9225
#
#     psfNdata  trailFlux  trailFluxErr    trailRa trailRaErr   trailDec  \
# 0       1681  33962.098    408.788180  11.033261       None -43.468719
# 1       1681 -11173.576    304.221200  11.033311       None -43.468733
# 2       1681 -12115.952    187.298000  11.033320       None -43.468740
# 3       1681   7064.795    124.020170  11.033100       None -43.468662
# 4       1681  14663.214           NaN  11.033210       None -43.468717
# ..       ...        ...           ...        ...        ...        ...
# 57      1681  48442.965      0.419553  11.033296       None -43.468714
# 58      1681  45334.043      0.229300  11.033268       None -43.468731
# 59      1681  37575.945      0.824940  11.033297       None -43.468733
# 60      1681  20347.232      2.099366  11.033273       None -43.468744
# 61      1681  21776.322      3.462251  11.033241       None -43.468726
#
#    trailDecErr  trailLength  trailLengthErr  trailAngle  trailAngleErr  \
# 0         None     0.346262        0.080995   96.155500      13.790262
# 1         None     0.293380        1.025684   65.369804     201.505860
# 2         None     1.241521        0.178249   85.357610       9.128689
# 3         None     1.039814        0.114490 -149.695940       7.481667
# 4         None     1.645423             NaN   91.217760            NaN
# ..         ...          ...             ...         ...            ...
# 57        None     0.916472             NaN -105.188850            NaN
# 58        None     0.719695             NaN  -93.482550            NaN
# 59        None     0.851981             NaN  -43.625885            NaN
# 60        None     0.648034             NaN  -69.158590            NaN
# 61        None     0.817013             NaN  -37.511467            NaN
#
#    trailChi2  trailNdata  trail_flag_edge dipoleMeanFlux dipoleMeanFluxErr  \
# 0       None           0            False           None              None
# 1       None           0            False           None              None
# 2       None           0            False           None              None
# 3       None           0            False           None              None
# 4       None           0            False           None              None
# ..       ...         ...              ...            ...               ...
# 57      None           0            False           None              None
# 58      None           0            False           None              None
# 59      None           0            False           None              None
# 60      None           0            False           None              None
# 61      None           0            False           None              None
#
#    dipoleFluxDiff dipoleFluxDiffErr dipoleLength dipoleAngle dipoleChi2  \
# 0            None              None         None        None       None
# 1            None              None         None        None       None
# 2            None              None         None        None       None
# 3            None              None         None        None       None
# 4            None              None         None        None       None
# ..            ...               ...          ...         ...        ...
# 57           None              None         None        None       None
# 58           None              None         None        None       None
# 59           None              None         None        None       None
# 60           None              None         None        None       None
# 61           None              None         None        None       None
#
#     dipoleNdata  forced_PsfFlux_flag  forced_PsfFlux_flag_edge  \
# 0             0                False                     False
# 1             0                False                     False
# 2             0                False                     False
# 3             0                False                     False
# 4             0                False                     False
# ..          ...                  ...                       ...
# 57            0                False                     False
# 58            0                False                     False
# 59            0                False                     False
# 60            0                False                     False
# 61            0                False                     False
#
#     forced_PsfFlux_flag_noGoodPixels  templateFlux  templateFluxErr       ixx  \
# 0                              False     96041.780       125.294760  0.107856
# 1                              False     79181.805         9.465317  0.357893
# 2                              False     78882.800         9.357190  0.322334
# 3                              False     65334.273        63.498657  0.164509
# 4                              False    100341.150        62.225628  0.248196
# ..                               ...           ...              ...       ...
# 57                             False     98748.690         6.611571  0.535923
# 58                             False     98656.970         7.634672  0.477327
# 59                             False     98769.290        32.605213  0.263791
# 60                             False    101691.370        29.653267  0.280899
# 61                             False    101398.320        20.208967  0.313983
#
#          iyy       ixy    ixxPSF    iyyPSF    ixyPSF  shape_flag  \
# 0   0.101837 -0.004331  0.098843  0.088932 -0.001170       False
# 1   0.363953 -0.001962  0.435012  0.414368  0.001033       False
# 2   0.342218 -0.071818  0.414511  0.412209 -0.002621       False
# 3   0.093036  0.046981  0.168317  0.184227 -0.011641       False
# 4   0.503087 -0.047577  0.230764  0.414697 -0.089702       False
# ..       ...       ...       ...       ...       ...         ...
# 57  0.491640 -0.028979  0.524647  0.487243 -0.022945       False
# 58  0.436397 -0.008620  0.461081  0.443642  0.005865       False
# 59  0.223925  0.025821  0.264376  0.231649  0.004114       False
# 60  0.251851 -0.010980  0.249027  0.218665 -0.019322       False
# 61  0.261078  0.013049  0.305188  0.274230 -0.010321       False
#
#     shape_flag_no_pixels  shape_flag_not_contained  shape_flag_parent_source  \
# 0                  False                     False                     False
# 1                  False                     False                     False
# 2                  False                     False                     False
# 3                  False                     False                     False
# 4                  False                     False                     False
# ..                   ...                       ...                       ...
# 57                 False                     False                     False
# 58                 False                     False                     False
# 59                 False                     False                     False
# 60                 False                     False                     False
# 61                 False                     False                     False
#
#     extendedness  reliability  isDipole  dipoleFitAttempted  \
# 0       0.031507     0.999905     False               False
# 1       0.213024     0.812284     False               False
# 2       0.328164     0.812703     False               False
# 3       0.274078     0.681681     False               False
# 4       0.195262     0.988622     False               False
# ..           ...          ...       ...                 ...
# 57      0.003030     0.999812     False               False
# 58      0.001121     0.999827     False               False
# 59      0.001742     0.998844     False               False
# 60      0.107210     0.149339     False               False
# 61      0.000410     0.150231     False               False
#
#     timeProcessedMjdTai timeWithdrawnMjdTai  bboxSize  pixelFlags  \
# 0          61217.418586                None        24       False
# 1          61219.424116                None        36       False
# 2          61219.424526                None        35       False
# 3          61221.419094                None        21       False
# 4          61222.415946                None        28       False
# ..                  ...                 ...       ...         ...
# 57         61081.934809                None        45       False
# 58         61081.901697                None        43       False
# 59         61081.883553                None        33       False
# 60         61081.882162                None        28       False
# 61         61081.924047                None        30       False
#
#     pixelFlags_bad  pixelFlags_cr  pixelFlags_crCenter  pixelFlags_edge  \
# 0            False          False                False            False
# 1            False          False                False            False
# 2            False          False                False            False
# 3            False          False                False            False
# 4            False          False                False            False
# ..             ...            ...                  ...              ...
# 57           False          False                False            False
# 58           False          False                False            False
# 59           False          False                False            False
# 60           False          False                False            False
# 61           False          False                False            False
#
#     pixelFlags_nodata  pixelFlags_nodataCenter  pixelFlags_interpolated  \
# 0               False                    False                    False
# 1               False                    False                    False
# 2               False                    False                    False
# 3               False                    False                    False
# 4               False                    False                    False
# ..                ...                      ...                      ...
# 57              False                    False                    False
# 58              False                    False                    False
# 59              False                    False                    False
# 60              False                    False                    False
# 61              False                    False                    False
#
#     pixelFlags_interpolatedCenter  pixelFlags_offimage  pixelFlags_saturated  \
# 0                           False                False                 False
# 1                           False                False                 False
# 2                           False                False                 False
# 3                           False                False                 False
# 4                           False                False                 False
# ..                            ...                  ...                   ...
# 57                          False                False                 False
# 58                          False                False                 False
# 59                          False                False                 False
# 60                          False                False                 False
# 61                          False                False                 False
#
#     pixelFlags_saturatedCenter  pixelFlags_suspect  pixelFlags_suspectCenter  \
# 0                        False               False                     False
# 1                        False               False                     False
# 2                        False               False                     False
# 3                        False               False                     False
# 4                        False               False                     False
# ..                         ...                 ...                       ...
# 57                       False               False                     False
# 58                       False               False                     False
# 59                       False               False                     False
# 60                       False               False                     False
# 61                       False               False                     False
#
#     pixelFlags_streak  pixelFlags_streakCenter  pixelFlags_injected  \
# 0               False                    False                False
# 1               False                    False                False
# 2               False                    False                False
# 3               False                    False                False
# 4               False                    False                False
# ..                ...                      ...                  ...
# 57              False                    False                False
# 58              False                    False                False
# 59              False                    False                False
# 60              False                    False                False
# 61              False                    False                False
#
#     pixelFlags_injectedCenter  pixelFlags_injected_template  \
# 0                       False                         False
# 1                       False                         False
# 2                       False                         False
# 3                       False                         False
# 4                       False                         False
# ..                        ...                           ...
# 57                      False                         False
# 58                      False                         False
# 59                      False                         False
# 60                      False                         False
# 61                      False                         False
#
#     pixelFlags_injected_templateCenter  glint_trail band_name
# 0                                False        False         i
# 1                                False        False         g
# 2                                False        False         g
# 3                                False        False         i
# 4                                False        False         z
# ..                                 ...          ...       ...
# 57                               False        False         i
# 58                               False        False         i
# 59                               False        False         r
# 60                               False        False         z
# 61                               False        False         z
#
# [62 rows x 102 columns]

# %%
df_forced = alerce_client.query_forced_photometry(oid, survey='lsst',
                                                  format='pandas')
display(df_forced)
# Out:
#    band           mjd survey_id                 oid      measurement_id  \
# 0     3  61203.444230      lsst  313629129709715483  170525524261077001
# 1     3  61217.416228      lsst  313629129709715483  170587116609732611
# 2     3  61217.416705      lsst  313629129709715483  170587116743950340
# 3     1  61217.420025      lsst  313629129709715483  170587117164429317
# 4     1  61217.420491      lsst  313629129709715483  170587117303889927
# 5     3  61219.419089      lsst  313629129709715483  170595944501870605
# 6     1  61219.422467      lsst  313629129709715483  170595944914485253
# 7     1  61219.422929      lsst  313629129709715483  170595945045032968
# 8     1  61221.414491      lsst  313629129709715483  170604740487413769
# 9     3  61221.417075      lsst  313629129709715483  170604740730683398
#
#           ra        dec          visit  detector      psfFlux  psfFluxErr  \
# 0  11.033299 -43.468731  2026061100498        87  -4969.40000  2865.93160
# 1  11.033293 -43.468727  2026062500645        25  40701.10000   396.92870
# 2  11.033293 -43.468727  2026062500646        25  41672.76000   407.22476
# 3  11.033293 -43.468727  2026062500649        59  71139.24000   333.53326
# 4  11.033293 -43.468727  2026062500650        69  69380.88000   330.43686
# 5  11.033293 -43.468727  2026062700882         5  -9104.83900   569.25476
# 6  11.033293 -43.468727  2026062700885        24 -12428.25400   408.84097
# 7  11.033293 -43.468727  2026062700886        17 -12648.16600   404.75050
# 8  11.033293 -43.468727  2026062900881        56    507.89508   421.77470
# 9  11.033293 -43.468727  2026062900883         8   3421.64330   443.88538
#
#    scienceFlux  scienceFluxErr band_name
# 0     91120.33      2922.76200         i
# 1    137918.66       414.05072         i
# 2    138858.67       418.84656         i
# 3    151056.39       339.89825         g
# 4    149709.30       337.85968         g
# 5     89305.79       568.59790         i
# 6     67136.86       410.04065         g
# 7     66922.40       405.23364         g
# 8     78494.31       418.24472         g
# 9    101233.78       442.46744         i

# %%
lc_params = {
    'use_mag': False,
    'use_flux': True,
    'show_yr': False,
    'figwidth': 8,
    'pheight': 3,
    'fontsize': 9,
    'alpha': 0.5,
}

# %%
df_dets.set_index('oid', inplace=True)
if len(df_forced) > 0:
    df_forced.set_index('oid', inplace=True)

epochs = {
    'detections': df_dets,
    'forced_photometry': df_forced,

}
d_objs = ms.group_data_sid_oid(
    sid=sid,
    oid=oid,
    df_dets=epochs['detections'].copy(),
    df_forced=epochs['forced_photometry'].copy() \
        if oid in epochs['forced_photometry'].index else pd.DataFrame(),
        lc_kwargs=ms.init_lc_kwargs()
    )

# %%
d_objs[sid][oid]['lc_kwargs']['show_forced'] = True

ms.plot_lc(d_objs=d_objs, lc_params=lc_params)

# %%
d_objs[sid][oid]['lc_kwargs']['show_flux'] = False
d_objs[sid][oid]['lc_kwargs']['show_forced'] = False

ms.plot_lc(d_objs=d_objs, lc_params=lc_params)
# Out:
# /home/ammunoz1/.local/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
d_objs[sid][oid]['lc_kwargs']['show_folded'] = True
d_objs[sid][oid]['lc_kwargs']['folded_period'] = period

ms.plot_lc(d_objs=d_objs, lc_params=lc_params)

# %% [markdown]
# ## Querying samples of objects <a class='anchor' id='query_many'></a>

# %% [markdown]
# The ALeRCE pipeline computes probabilities for different classifiers. At this time, we classify LSST objects using the ALeRCE stamp classifier (still in beta mode); a first model was stamp_classifier_rubin_beta version 2.0.1, while the latest model is stamp_classifier_rubin_beta_20260421 version 2.0.2. These are deep learning classifiers based on each object's first alert image cutouts (manuscript in preparation; see [Carrasco-Davis et al. 2021](https://ui.adsabs.harvard.edu/abs/2021AJ....162..231C/abstract) for a similar version using the ZTF public alert stream). Both have classified all Rubin objects, with the latest model using a more up-to-date training set. The stamp classifier taxonomy includes five classes, and is used to pre-select transient candidates (e.g. supernovae, tidal disruption events) early after their first light.
#
# We search for 15 objects that had their first detection between Mar 1 2026 and June 27 2026, their last detection after Mar 10 2026, have 30 detections or more, and have the highest probability of being a supernova (SN) according to the latest stamp classifier, as

# %%
def utc_to_mjd(time):
    return Time(time, format='isot', scale='utc').mjd

# %%
firstmjd_min = utc_to_mjd('2026-03-01T00:00:00')
firstmjd_max = utc_to_mjd('2026-06-27T00:00:00')
print(firstmjd_min, firstmjd_max)

lastmjd_min = utc_to_mjd('2026-03-10T00:00:00')
print(lastmjd_min)

n_det_min = 30
n_objs = 15

df_objs = alerce_client.query_objects(
    survey='lsst',
    classifier='stamp_classifier_rubin_beta_20260421',
    class_name='SN',
    n_det=[n_det_min, None],
    firstmjd=[firstmjd_min, firstmjd_max],
    lastmjd=[lastmjd_min, None],
    page_size=n_objs,
    order_by='probability',
    order_mode='DESC',
    format='pandas'
)
display(df_objs)
# Out:
# 61100.0 61218.0
# 61109.0
#                    oid  tid  sid      meanra   meandec       sigmara  \
# 0   170094456365121569    1    1  150.842813  2.963688  8.342428e-07
# 1   170226393632735260    1    1  149.979878  0.537539  8.241714e-07
# 2   170107660764446767    1    1  151.576121  1.848071  8.574231e-07
# 3   170389126977683571    1    1  150.212951  2.713226  1.522382e-06
# 4   170389126953566274    1    1  149.907399  2.609188  9.882865e-07
# 5   170226393570345033    1    1  148.788193  2.670862  9.733727e-07
# 6   170226393351716950    1    1  150.403671  3.103615  8.943046e-07
# 7   170411112000913487    1    1  151.163536  2.507444  4.168477e-07
# 8   170261592629837872    1    1  151.134202  3.315060  3.340845e-07
# 9   170226393301385313    1    1  148.720919  2.580764  1.159545e-06
# 10  170094456349392906    1    1  148.711587  2.431373  1.337114e-06
# 11  170270398384963595    1    1  149.850427  3.703827  5.137982e-07
# 12  170274770629689377    1    1  149.759997  1.742217  2.083841e-06
# 13  170270398108139547    1    1  150.420433  2.038172  1.076016e-06
# 14  170094456400773135    1    1  149.635684  1.269348  4.094198e-07
#
#         sigmadec      firstmjd       lastmjd   deltamjd  n_det  n_forced  \
# 0   8.314584e-07  61105.095334  61189.036344  83.941010     68       181
# 1   8.577625e-07  61135.002822  61178.983683  43.980862     60        79
# 2   8.736672e-07  61108.085916  61204.973907  96.887990     94       175
# 3   1.546876e-06  61172.002308  61204.973907  32.971599     40        74
# 4   9.704551e-07  61172.002308  61204.981752  32.979444     57        81
# 5   9.880083e-07  61135.002822  61152.083609  17.080787     49        80
# 6   8.960108e-07  61134.999535  61204.973907  69.974372     76       177
# 7   4.176062e-07  61176.986842  61205.983739  28.996897     67        82
# 8   3.360418e-07  61143.054629  61204.981235  61.926606     73       131
# 9   1.205134e-06  61134.999535  61204.973907  69.974372     85       169
# 10  1.379034e-06  61105.095334  61178.981196  73.885862     69       140
# 11  5.103729e-07  61145.128659  61204.981752  59.853093     95       112
# 12  2.166814e-06  61146.080821  61190.973753  44.892933     35        78
# 13  1.077061e-06  61145.126260  61204.973907  59.847647     49       111
# 14  4.186182e-07  61105.095334  61179.992111  74.896777    105       147
#
#     n_non_det stellar class_name                       classifier_name  \
# 0           0    None         SN  stamp_classifier_rubin_beta_20260421
# 1           0    None         SN  stamp_classifier_rubin_beta_20260421
# 2           0    None         SN  stamp_classifier_rubin_beta_20260421
# 3           0    None         SN  stamp_classifier_rubin_beta_20260421
# 4           0    None         SN  stamp_classifier_rubin_beta_20260421
# 5           0    None         SN  stamp_classifier_rubin_beta_20260421
# 6           0    None         SN  stamp_classifier_rubin_beta_20260421
# 7           0    None         SN  stamp_classifier_rubin_beta_20260421
# 8           0    None         SN  stamp_classifier_rubin_beta_20260421
# 9           0    None         SN  stamp_classifier_rubin_beta_20260421
# 10          0    None         SN  stamp_classifier_rubin_beta_20260421
# 11          0    None         SN  stamp_classifier_rubin_beta_20260421
# 12          0    None         SN  stamp_classifier_rubin_beta_20260421
# 13          0    None         SN  stamp_classifier_rubin_beta_20260421
# 14          0    None         SN  stamp_classifier_rubin_beta_20260421
#
#    classifier_version  probability  ranking
# 0               2.0.2     0.986570        1
# 1               2.0.2     0.985418        1
# 2               2.0.2     0.980048        1
# 3               2.0.2     0.967129        1
# 4               2.0.2     0.959600        1
# 5               2.0.2     0.958356        1
# 6               2.0.2     0.951708        1
# 7               2.0.2     0.947267        1
# 8               2.0.2     0.945664        1
# 9               2.0.2     0.939747        1
# 10              2.0.2     0.937733        1
# 11              2.0.2     0.898348        1
# 12              2.0.2     0.880481        1
# 13              2.0.2     0.863533        1
# 14              2.0.2     0.833545        1

# %% [markdown]
# We display their mean coordinates, as well as some of their properties

# %%
def plot_scatter(df=None, title='', prop_x=None, prop_y=None,
                 prop_color=None, figsize=(6, 3), alpha=0.7):
    fontsize = 9
    plt.rcParams.update({'font.size': fontsize})
    
    fig, ax = plt.subplots(figsize=figsize)

    if prop_color is None:
        sc = ax.scatter(df[prop_x], df[prop_y], s=3, alpha=alpha)
    else:
        cmap = 'coolwarm'
        sc = ax.scatter(df[prop_x], df[prop_y],
                        c=df[prop_color],
                        cmap=cmap, s=10, alpha=alpha)
        plt.colorbar(sc, ax=ax, label=prop_color)
    
    ax.set_xlabel(prop_x)
    ax.set_ylabel(prop_y)
    ax.set_title(title)
    
    plt.tight_layout()
    plt.rcParams.update({'font.size': 12})

# %%
props_x = ['meanra', 'firstmjd']
props_x = [x.lower() for x in props_x]
props_y = ['meandec', 'deltamjd']
props_y = [x.lower() for x in props_y]
props_color = ['probability', 'n_det']
props_color = [x.lower() for x in props_color]

for (prop_x, prop_y, prop_color) in zip(
    props_x, props_y, props_color):
    plot_scatter(df=df_objs,
                 prop_x=prop_x, prop_y=prop_y,
                 prop_color=prop_color)

# %% [markdown]
# ### Generate an ALeRCE LSST Explorer link <a class='anchor' id='explorer_url'></a>

# %% [markdown]
# Note that the interface accepts a maximum of 200 objects

# %%
def print_link_lsst(index=None, classifier='stamp_classifier_rubin_beta_20260421'):
    if len(index) == 1:
        expr = 'https://lsst.alerce.online/object/' + str(index[0]) \
               + '?survey=lsst'
    else:
        expr1 = 'https://lsst.alerce.online/?oid='
        expr2 = ','.join(list([str(x) for x in index]))
        expr3 = '&survey=lsst'
        expr4 = '&classifier=' + classifier + '&page=1'
        expr = expr1 + expr2 + expr3 + expr4
    
    display(HTML("<a href='%s' target=\"_blank\"> %s <a>" % (expr, expr)))

# %%
index = pd.unique(df_objs['oid'])
print_link_lsst(index=index)
# Out:
# <a href='https://lsst.alerce.online/?oid=170094456365121569,170226393632735260,170107660764446767,170389126977683571,170389126953566274,170226393570345033,170226393351716950,170411112000913487,170261592629837872,170226393301385313,170094456349392906,170270398384963595,170274770629689377,170270398108139547,170094456400773135&survey=lsst&classifier=stamp_classifier_rubin_beta_20260421&page=1' target="_blank"> https://lsst.alerce.online/?oid=170094456365121569,170226393632735260,170107660764446767,170389126977683571,170389126953566274,170226393570345033,170226393351716950,170411112000913487,170261592629837872,170226393301385313,170094456349392906,170270398384963595,170274770629689377,170270398108139547,170094456400773135&survey=lsst&classifier=stamp_classifier_rubin_beta_20260421&page=1 <a>

# %% [markdown]
# ### Object lists <a class='anchor' id='query_list'></a>

# %% [markdown]
# Note that we can also search by a list of known object identifiers

# %%
oids = [
    313853517490028563,
    313695087485255753,
    313853517444939794,
]

# %%
df_objs = alerce_client.query_objects(
    oid=oids,
    survey='lsst',
    format='pandas'
)
display(df_objs)
# Out:
#                   oid  tid  sid      meanra    meandec       sigmara  \
# 0  313853517490028563    1    1  150.021002   0.550432  2.737409e-07
# 1  313695087485255753    1    1   10.240453 -43.631762  8.784008e-07
# 2  313853517490028563    1    1  150.021002   0.550432  2.737409e-07
# 3  313695087485255753    1    1   10.240453 -43.631762  8.784008e-07
# 4  313853517444939794    1    1  149.738956   2.220690  1.513282e-07
# 5  313853517444939794    1    1  149.738956   2.220690  1.513282e-07
#
#        sigmadec      firstmjd       lastmjd    deltamjd  n_det  n_forced  \
# 0  2.781927e-07  61024.245933  61204.981752  180.735819    809       697
# 1  8.479267e-07  60988.123073  61235.404704  247.281630    166        32
# 2  2.781927e-07  61024.245933  61204.981752  180.735819    809       697
# 3  8.479267e-07  60988.123073  61235.404704  247.281630    166        32
# 4  1.523100e-07  61024.245933  61205.988991  181.743059   1403      1217
# 5  1.523100e-07  61024.245933  61205.988991  181.743059   1403      1217
#
#    n_non_det stellar class_name                       classifier_name  \
# 0          0    None        AGN  stamp_classifier_rubin_beta_20260421
# 1          0    None        AGN  stamp_classifier_rubin_beta_20260421
# 2          0    None        AGN           stamp_classifier_rubin_beta
# 3          0    None        AGN           stamp_classifier_rubin_beta
# 4          0    None        AGN  stamp_classifier_rubin_beta_20260421
# 5          0    None        AGN           stamp_classifier_rubin_beta
#
#   classifier_version  probability  ranking
# 0              2.0.2     0.946849        1
# 1              2.0.2     0.939654        1
# 2              2.0.1     0.911964        1
# 3              2.0.1     0.889554        1
# 4              2.0.2     0.830418        1
# 5              2.0.1     0.646737        1

# %%
index = [oid for oid in oids if oid in df_objs['oid'].tolist()]
print_link_lsst(index=index)
# Out:
# <a href='https://lsst.alerce.online/?oid=313853517490028563,313695087485255753,313853517444939794&survey=lsst&classifier=stamp_classifier_rubin_beta_20260421&page=1' target="_blank"> https://lsst.alerce.online/?oid=313853517490028563,313695087485255753,313853517444939794&survey=lsst&classifier=stamp_classifier_rubin_beta_20260421&page=1 <a>
